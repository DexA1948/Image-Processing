# %%
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

# %%
img=cv2.imread("/content/drive/MyDrive/ipphotos/OIF.jfif", 0)

# %%
histr=cv2.calcHist([img],[0],None,[256],[0,256])
plt.plot(histr)
