# %%
dst = cv2.Laplacian(src_gray, ddepth, ksize=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f93730aad179> in <module>()
# ----> 1 dst = cv2.Laplacian(src_gray, ddepth, ksize=4)
#
# NameError: name 'src_gray' is not defined

# %%
import cv2
from google.colab.patches import cv2_imshow
